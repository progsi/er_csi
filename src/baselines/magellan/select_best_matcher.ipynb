# %% [markdown]
# # Introduction
#
# This IPython notebook illustrates how to select the best learning based matcher. First, we need to import py_entitymatching package and other libraries as follows:

# %% [markdown]
# # Preprocessing from rSupCon directory

# %%
# Import py_entitymatching package
import py_entitymatching as em
import os
import pandas as pd
import copy


# Set the seed value 
seed = 0


def init_dataset_from_rsupcon(metadata_parquet_file, dataset_file, split='TRAIN', shs_side=False):
    
    def clean_string(text):
        import re
        pattern = re.compile('[^a-zA-Z0-9\s]')
        cleaned_text = re.sub(pattern, '', text)
        return cleaned_text

    """
    A = pd.read_parquet(path + table_filename).rename({"title": "video_title"}, axis=1).drop_duplicates(
        subset=["yt_id"]
    ).fillna('')
    A.description = A.description.apply(clean_string)
    B = copy.copy(A)
    """
    df_dataset = pd.read_csv(dataset_file)
    df_metadata = pd.read_parquet(metadata_parquet_file).query(f"split == '{split}'")
    
    if shs_side:
        A = df_metadata[["yt_id", "title", "performer"]].drop_duplicates(
            subset=["yt_id"]).dropna(subset=["yt_id"]).rename({"title": "video_title", 
                                                               "performer": "channel_name"}, axis=1)
        A["description"] = 'DESCRIPTION'
        A["keywords"] = 'KEYWORDS'
    else:
        A = df_metadata[["yt_id", "video_title", "channel_name", "description", "keywords"]].drop_duplicates(
            subset=["yt_id"]).dropna(subset=["yt_id"])
    
    B = df_metadata[["yt_id", "video_title", "channel_name", "description", "keywords"]].drop_duplicates(
        subset=["yt_id"]).dropna(subset=["yt_id"])
    B.description = B.description.apply(clean_string)
    
    A = A.fillna('')
    B = B.fillna('')

    def enrich(pairs):
        data = pd.merge(
            A.add_prefix("ltable_").rename({"ltable_yt_id": "ltable_id"}, axis=1),
            pd.merge(
                pairs[["ltable_id", "rtable_id", "label"]],
                B.add_prefix("rtable_").rename({"rtable_yt_id": "rtable_id"}, axis=1),
                on="rtable_id",
                how="left"
                ), 
            on="ltable_id",
            how="right"
        )
        # id formatting
        data["_id"] = range(0, len(data))
        
        # col reordering
        data = data[['_id', 'ltable_id', 'rtable_id', 'ltable_video_title', 
                        'ltable_channel_name', 'ltable_description', 'ltable_keywords', 
                        'rtable_video_title', 'rtable_channel_name', 'rtable_description', 
                        'rtable_keywords', 'label']]
        return data
        
    S = enrich(df_dataset)

    datasets_dir = em.get_install_path() + os.sep + 'datasets'

    path_A = datasets_dir + os.sep + 'shs100k2_yt_A.csv'
    path_B = datasets_dir + os.sep + 'shs100k2_yt_B.csv'
    path_labeled_data = datasets_dir + os.sep + 'shs100k2_yt_labeled.csv'

    os.remove(path_A) if os.path.exists(path_A) else None
    os.remove(path_B) if os.path.exists(path_B) else None
    os.remove(path_labeled_data) if os.path.exists(path_labeled_data) else None

    em.to_csv_metadata(A, path_A)
    em.to_csv_metadata(B, path_B)
    em.to_csv_metadata(S, path_labeled_data)

    # reading in
    A = em.read_csv_metadata(path_A, key='yt_id')
    B = em.read_csv_metadata(path_B, key='yt_id')

    S = em.read_csv_metadata(path_labeled_data, key='_id',
                            ltable=A, rtable=B, 
                            fk_ltable='ltable_id', fk_rtable='rtable_id')

    # remove the files
    os.remove(path_A) if os.path.exists(path_A) else None
    os.remove(path_B) if os.path.exists(path_B) else None
    os.remove(path_labeled_data) if os.path.exists(path_labeled_data) else None
    
    return A, B, S


metadata_parquet_file="/data/csi_datasets/shs100k2_yt.parquet"
dataset_file="/home/repos/contrastive-product-matching/data/raw/shs100k2_yt/train.csv"


A, B, S = init_dataset_from_rsupcon(metadata_parquet_file, dataset_file)
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
# SIMON: blocking test
ob = em.OverlapBlocker()
#ob.block_tables(A, B, 'video_title', 'video_title', word_level=True, overlap_size=1, 
#                    l_output_attrs=['video_title', 'channel_name', 'description'], 
#                    r_output_attrs=['video_title', 'channel_name', 'description'],
#                    show_progress=False)

# %%
# Split S into I an J
IJ = em.split_train_test(S, train_proportion=0.5, random_state=0)
I = IJ['train']
J = IJ['test']

# %% [markdown]
# # Selecting the Best learning-based matcher

# %% [markdown]
# This, typically involves the following steps:
# 1. Creating a set of learning-based matchers
# 2. Creating features
# 3. Extracting feature vectors
# 4. Selecting the best learning-based matcher using k-fold cross validation
# 5. Debugging the matcher (and possibly repeat the above steps)

# %% [markdown]
# ## Creating a set of learning-based matchers

# %% [markdown]
# First, we need to create a set of learning-based matchers. The following matchers are supported in Magellan: (1) decision tree, (2) random forest, (3) naive bayes, (4) svm, (5) logistic regression, and (6) linear regression.

# %%
# Create a set of ML-matchers
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')

# %% [markdown]
# ## Creating features
#
# Next, we need to create a set of features for the development set. Magellan provides a way to automatically generate features based on the attributes in the input tables. For the purposes of this guide, we use the automatically generated features.

# %%
# Generate a set of features
F = em.get_features_for_matching(A, B, validate_inferred_attr_types=False)

# %% [markdown]
# We observe that there were 20 features generated. As a first step, lets say that we decide to use only 'year' related features.

# %%
F.feature_name
# Out:
# 0           video_title_video_title_jac_qgm_3_qgm_3
# 1       video_title_video_title_cos_dlm_dc0_dlm_dc0
# 2                       video_title_video_title_mel
# 3                  video_title_video_title_lev_dist
# 4                   video_title_video_title_lev_sim
# 5         channel_name_channel_name_jac_qgm_3_qgm_3
# 6     channel_name_channel_name_cos_dlm_dc0_dlm_dc0
# 7     channel_name_channel_name_jac_dlm_dc0_dlm_dc0
# 8                     channel_name_channel_name_mel
# 9                channel_name_channel_name_lev_dist
# 10                channel_name_channel_name_lev_sim
# 11                    channel_name_channel_name_nmw
# 12                     channel_name_channel_name_sw
# 13          description_description_jac_qgm_3_qgm_3
# 14      description_description_cos_dlm_dc0_dlm_dc0
# 15                keywords_keywords_jac_qgm_3_qgm_3
# 16            keywords_keywords_cos_dlm_dc0_dlm_dc0
# Name: feature_name, dtype: object

# %% [markdown]
# ## Extracting feature vectors
#
# In this step, we extract feature vectors using the development set and the created features.

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='label',
                            show_progress=False)

# %%
A
# Out:
#              yt_id  \
# 0      E3lw8gaHs04
# 1      aPpJPTJc1lU
# 2      R44waInkjgI
# 3      NPRSkMIqgQA
# 4      piVtpRkhJTA
# ...            ...
# 71654  2S3cauISpNw
# 71655  Q6ix7lWPDAQ
# 71656  0JP_ZipG5Z0
# 71657  j7MC3ckUaDA
# 71658  I0K3uBr6flA
#
#                                                                              video_title  \
# 0              George Gershwin "Summertime" Helen Jepson '36 "Porgy and Bess" Remastered
# 1                                                            Billie Holiday - Summertime
# 2                            Anne Brown "Summertime" from Original Porgy and Bess (1940)
# 3                              Saunders King Rhythm - Summertime (Rhythm Recordings 2-A)
# 4                                                                  The Ravens-Summertime
# ...                                                                                  ...
# 71654  The Sachal Ensemble - Give Me Love (Give Me Peace On Earth) (Audio) ft. Seu Jorge
# 71655                                         Gary Stewart - Ain't Living Long Like This
# 71656                                     Rodney Crowell - I ain't living long like this
# 71657                                      Dream Syndicate - Ain't living Long Like This
# 71658           Waylon Jennings Tribute-I Ain't Living Long Like This by Brooks and Dunn
#
#                channel_name  \
# 0                 jonthesYT
# 1                OnlyJazzHQ
# 2                    bsgs98
# 3                 boogaludo
# 4      oldiesbutgoodies4you
# ...                     ...
# 71654    SachalEnsembleVEVO
# 71655          steve fizzle
# 71656            baalhabeit
# 71657               Jay Dog
# 71658         On'ry Waymore
#
#                                                                                                description  \
# 0      Helen Jepson, Metropolitan Opera star, singing Gershwin's "Summertime" from "Porgy and Bess" in ...
# 1      Performer(s): « Billie Holiday » & « Billie Holiday & Her Orchestra »\n« Summertime »\nAudio : V...
# 2      "Introduction" and "Summertime"\r\nFrom the Opera, "Porgy and Bess"\r\nMusic by George Gershwin\...
# 3      backed with "Swinging Door Groove"\n\nrecorded in San Francisco, June 1942\n\nCarlos Santana mer...
# 4      This song has been covered many many times by artists such as Sam Cooke,Marv Johnson,Ella Fitzge...
# ...                                                                                                    ...
# 71654  Music video by The Sachal Ensemble performing Give Me Love (Give Me Peace On Earth). (C) 2016 Un...
# 71655                                                           Gary Stewart - Ain't Living Long Like This
# 71656                    the original version,\n\nout of Rodney's Crowell CD "Ain't Living Long Like This"
# 71657                                                                                                  NaN
# 71658  Song: I Ain't Living Long Like This\nArtist: Brooks and Dunn\nAlbum:  I've Always Been Crazy- A ...
#
#                                                                                                   keywords
# 0                                                 ['George Gershwin' 'Summertime (song)' 'Porgy And Bess']
# 1      ['Jazz' 'Mp3' 'Mp4' 'HQ' 'Haute Qualité' 'High Quality' 'HD' 'Vidéo'\n 'Clip' 'Musical' 'Musica'...
# 2      ['Broadway' 'folk' 'Original cast' 'Porgy and Bess' 'opera' 'sound'\n 'track' 'Summertime' 'Anne...
# 3                   ['vinyl' '78 rpm' 'shellac' 'Schellack' 'Jazz' 'Deborah Sara King'\n 'Carlos Santana']
# 4      ['jazz' 'r&b' 'pop' 'The' 'Ravens' 'Summertime' 'Sam' 'Cooke' 'Porgy'\n 'and' 'Bess' 'Jimmy' 'Ri...
# ...                                                                                                    ...
# 71654  ['The' 'Sachal' 'Ensemble' 'Give' 'Me' 'Love' '(Give' 'Peace' 'On'\n 'Earth)' 'Universal' 'Music...
# 71655  ['video' 'Gary Stewart (Musical Artist)'\n "Ain't Living Long Like This (Musical Album)"\n "Gary...
# 71656  ['rodney' 'crowell' 'emmylou' 'harris' 'waylon' 'jennings' 'country'\n "ain't" "livin'" 'long' '...
# 71657  ['dream syndicate' "ain't living long like this"\n 'aint living long like this' 'emmylou harris'...
# 71658  ['Waylon Jennings (Musical Artist)' 'Brooks & Dunn (Musical Artist)'\n 'Country (Musical Genre)'...
#
# [71659 rows x 5 columns]

# %%
# Display first few rows
H.head()
# Out:
#        _id    ltable_id    rtable_id  video_title_video_title_jac_qgm_3_qgm_3  \
# 333    333  a527ZOSJ0rY  dGLs1chXTWM                                 0.027027
# 6392  6392  M6e-RlMkRx8  nAZqJg-XnU8                                 0.012987
# 4786  4786  lfbwBdaSanw  IGjgocfuU_o                                 0.035294
# 357    357  nt4emPn6du4  drPGfa2-3XE                                 0.000000
# 9663  9663  EYJKKoZc9PA  xf1N4dUPw6A                                 0.000000
#
#       video_title_video_title_cos_dlm_dc0_dlm_dc0  \
# 333                                      0.000000
# 6392                                     0.142857
# 4786                                     0.129099
# 357                                      0.000000
# 9663                                     0.000000
#
#       video_title_video_title_mel  video_title_video_title_lev_dist  \
# 333                      0.486724                                29
# 6392                     0.559921                                34
# 4786                     0.539805                                53
# 357                      0.511724                                46
# 9663                     0.367725                                44
#
#       video_title_video_title_lev_sim  \
# 333                          0.236842
# 6392                         0.150000
# 4786                         0.171875
# 357                          0.178571
# 9663                         0.102041
#
#       channel_name_channel_name_jac_qgm_3_qgm_3  \
# 333                                         0.0
# 6392                                        0.0
# 4786                                        0.0
# 357                                         0.0
# 9663                                        0.0
#
#       channel_name_channel_name_cos_dlm_dc0_dlm_dc0  ...  \
# 333                                             0.0  ...
# 6392                                            0.0  ...
# 4786                                            0.0  ...
# 357                                             0.0  ...
# 9663                                            0.0  ...
#
#       channel_name_channel_name_mel  channel_name_channel_name_lev_dist  \
# 333                        0.000000                                12.0
# 6392                       0.374126                                21.0
# 4786                       0.451282                                12.0
# 357                        0.513919                                11.0
# 9663                       0.357143                                 7.0
#
#       channel_name_channel_name_lev_sim  channel_name_channel_name_nmw  \
# 333                            0.000000                           -5.0
# 6392                           0.045455                           -8.0
# 4786                           0.076923                           -2.0
# 357                            0.214286                            2.0
# 9663                           0.000000                            0.0
#
#       channel_name_channel_name_sw  description_description_jac_qgm_3_qgm_3  \
# 333                            0.0                                 0.029289
# 6392                           1.0                                 0.006557
# 4786                           1.0                                 0.024194
# 357                            3.0                                 0.061091
# 9663                           1.0                                      NaN
#
#       description_description_cos_dlm_dc0_dlm_dc0  \
# 333                                      0.000000
# 6392                                     0.000000
# 4786                                     0.099015
# 357                                      0.017991
# 9663                                          NaN
#
#       keywords_keywords_jac_qgm_3_qgm_3  \
# 333                            0.094340
# 6392                           0.048387
# 4786                           0.053097
# 357                            0.080831
# 9663                           0.064103
#
#       keywords_keywords_cos_dlm_dc0_dlm_dc0  label
# 333                                     0.0      0
# 6392                                    0.0      0
# 4786                                    0.0      0
# 357                                     0.0      0
# 9663                                    0.0      0
#
# [5 rows x 21 columns]

# %%
# Check if the feature vectors contain missing values
# A return value of True means that there are missing values
any(pd.notnull(H))
# Out:
# True

# %% [markdown]
# We observe that the extracted feature vectors contain missing values. We have to impute the missing values for the learning-based matchers to fit the model correctly. For the purposes of this guide, we impute the missing value in a column with the mean of the values in that column.

# %%
# Impute feature vectors with the mean of the column values.
H = em.impute_table(H, 
                exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
                strategy='mean')
# Out:
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/matcher/matcherutils.py:224: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   imp.statistics_[pd.np.isnan(imp.statistics_)] = val_all_nans

# %% [markdown]
# ## Selecting the best matcher using cross-validation
#
# Now, we select the best matcher using k-fold cross-validation. For the purposes of this guide, we use five fold cross validation and use 'precision' metric to select the best matcher.

# %%
# Select the best ML matcher using CV
result = em.select_matcher([dt, rf, svm, ln, lg], table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
        k=5,
        target_attr='label', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.720015        0.790833    0.753427
# 1            RF           0.954104        0.782202    0.859522
# 2           SVM           0.800000        0.016272    0.031836
# 3        LinReg           0.997826        0.612561    0.758504
# 4        LogReg                NaN             NaN         NaN

# %%
result['drill_down_cv_stats']['precision']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3        LinReg
# 4        LogReg
#
#                                                                             Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x7f13143d2b50>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x7f13143d2c90>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x7f13143d2990>
# 3  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x7f13143d2250>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x7f13143d21d0>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.688623  0.684848  0.757396  0.720779  0.748428    0.720015
# 1          5  0.973451  0.918033  0.976744  0.956140  0.946154    0.954104
# 2          5  1.000000  1.000000  1.000000  1.000000  0.000000    0.800000
# 3          5  1.000000  0.989130  1.000000  1.000000  1.000000    0.997826
# 4          5       NaN       NaN       NaN       NaN       NaN         NaN

# %%
result['drill_down_cv_stats']['recall']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3        LinReg
# 4        LogReg
#
#                                                                             Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x7f13143d2b50>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x7f13143d2c90>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x7f13143d2990>
# 3  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x7f13143d2250>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x7f13143d21d0>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.798611  0.768707  0.831169  0.792857  0.762821    0.790833
# 1          5  0.763889  0.761905  0.818182  0.778571  0.788462    0.782202
# 2          5  0.013889  0.027211  0.025974  0.014286  0.000000    0.016272
# 3          5  0.597222  0.619048  0.558442  0.621429  0.666667    0.612561
# 4          5       NaN       NaN       NaN       NaN       NaN         NaN

# %%
result['drill_down_cv_stats']['f1']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3        LinReg
# 4        LogReg
#
#                                                                             Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x7f13143d2b50>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x7f13143d2c90>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x7f13143d2990>
# 3  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x7f13143d2250>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x7f13143d21d0>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.739550  0.724359  0.792570  0.755102  0.755556    0.753427
# 1          5  0.856031  0.832714  0.890459  0.858268  0.860140    0.859522
# 2          5  0.027397  0.052980  0.050633  0.028169  0.000000    0.031836
# 3          5  0.747826  0.761506  0.716667  0.766520  0.800000    0.758504
# 4          5       NaN       NaN       NaN       NaN       NaN         NaN

# %% [markdown]
# ### Debug X (Random Forest)

# %%
# Split H into P and Q
PQ = em.split_train_test(H, train_proportion=0.5, random_state=0)
P = PQ['train']
Q = PQ['test']

# %%
# Debug RF matcher using GUI
# FIXME: ALWAYS CRASHES!
#em.vis_debug_rf(rf, P, Q, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'], target_attr='label')

# %%
# Add a feature to do Jaccard on title + authors and add it to F

# Create a feature declaratively
sim = em.get_sim_funs_for_matching()
tok = em.get_tokenizers_for_matching()
feature_string = """jaccard(wspace((ltuple['video_title'] + ' ' + ltuple['description']).lower()), 
                            wspace((rtuple['video_title'] + ' ' + rtuple['description']).lower()))"""
feature = em.get_feature_fn(feature_string, sim, tok)

# Add feature to F
em.add_feature(F, 'jac_ws_video_title_description', feature)
# Out:
# True

# %%
# Convert I into feature vectors using updated F
H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='label',
                            show_progress=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-0c306bca63e7> in <module>
#       3                             feature_table=F,
#       4                             attrs_after='label',
# ----> 5                             show_progress=False)
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/feature/extractfeatures.py in extract_feature_vecs(candset, attrs_before, feature_table, attrs_after, verbose, show_progress, n_jobs, FeatureExtractor)
#     227         show_progress=show_progress
#     228     )
# --> 229     feat_vals = feature_extractor.extract_from(candset)
#     230
#     231     # (Matt) ParallelFeatureExtractor implementation ends here; the rest is formatting
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/feature/extractfeatures.py in extract_from(self, candset)
#      72                 self.show_progress and i == len(c_splits) - 1
#      73             )
# ---> 74             for i, c_split in enumerate(c_splits)
#      75         )
#      76
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1046             # remaining jobs.
#    1047             self._iterating = False
# -> 1048             if self.dispatch_one_batch(iterator):
#    1049                 self._iterating = self._original_iterator is not None
#    1050
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     864                 return False
#     865             else:
# --> 866                 self._dispatch(tasks)
#     867                 return True
#     868
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     782         with self._lock:
#     783             job_idx = len(self._jobs)
# --> 784             job = self._backend.apply_async(batch, callback=cb)
#     785             # A job can complete so quickly than its callback is
#     786             # called before we get here, causing self._jobs to
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/joblib/parallel.py in __call__(self)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/joblib/parallel.py in <listcomp>(.0)
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     262             return [func(*args, **kwargs)
# --> 263                     for func, args, kwargs in self.items]
#     264
#     265     def __reduce__(self):
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/feature/extractfeatures.py in get_feature_vals_by_cand_split(pickled_obj, fk_ltable_idx, fk_rtable_idx, l_df, r_df, candsplit, show_progress)
#     299         r_tuple = r_dict[fk_rtable_val]
#     300
# --> 301         f = apply_feat_fns(l_tuple, r_tuple, feature_table)
#     302         feat_vals.append(f)
#     303
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/feature/extractfeatures.py in apply_feat_fns(tuple1, tuple2, feat_dict)
#     315     # Compute the feature value by applying the feature function to the input
#     316     #  tuples.
# --> 317     feat_vals = [f(tuple1, tuple2) for f in feat_funcs]
#     318     # Return a dictionary where the keys are the feature names and the values
#     319     #  are the feature values.
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/feature/extractfeatures.py in <listcomp>(.0)
#     315     # Compute the feature value by applying the feature function to the input
#     316     #  tuples.
# --> 317     feat_vals = [f(tuple1, tuple2) for f in feat_funcs]
#     318     # Return a dictionary where the keys are the feature names and the values
#     319     #  are the feature values.
#
# <string> in fn(ltuple, rtuple)
#
# TypeError: can only concatenate str (not "float") to str

# %%
# Check whether the updated F improves X (Random Forest)
result = em.select_matcher([rf], table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
        k=5,
        target_attr='label', metric_to_select_matcher='f1', random_state=0)
result['drill_down_cv_stats']['f1']
# Out:
#   Name  \
# 0   RF
#
#                                                                     Matcher  \
# 0  <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x7f13143d2c90>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4   Fold 5  Mean score
# 0          5  0.856031  0.832714  0.890459  0.858268  0.86014    0.859522

# %%
# Select the best matcher again using CV
result = em.select_matcher([dt, rf, svm, ln, lg], table=H, 
        exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
        k=5,
        target_attr='label', metric_to_select_matcher='f1', random_state=0)
result['cv_stats']
# Out:
#         Matcher  Average precision  Average recall  Average f1
# 0  DecisionTree           0.720015        0.790833    0.753427
# 1            RF           0.954104        0.782202    0.859522
# 2           SVM           0.800000        0.016272    0.031836
# 3        LinReg           0.997826        0.612561    0.758504
# 4        LogReg                NaN             NaN         NaN

# %%
result['drill_down_cv_stats']['f1']
# Out:
#            Name  \
# 0  DecisionTree
# 1            RF
# 2           SVM
# 3        LinReg
# 4        LogReg
#
#                                                                             Matcher  \
# 0          <py_entitymatching.matcher.dtmatcher.DTMatcher object at 0x7f13143d2b50>
# 1          <py_entitymatching.matcher.rfmatcher.RFMatcher object at 0x7f13143d2c90>
# 2        <py_entitymatching.matcher.svmmatcher.SVMMatcher object at 0x7f13143d2990>
# 3  <py_entitymatching.matcher.linregmatcher.LinRegMatcher object at 0x7f13143d2250>
# 4  <py_entitymatching.matcher.logregmatcher.LogRegMatcher object at 0x7f13143d21d0>
#
#    Num folds    Fold 1    Fold 2    Fold 3    Fold 4    Fold 5  Mean score
# 0          5  0.739550  0.724359  0.792570  0.755102  0.755556    0.753427
# 1          5  0.856031  0.832714  0.890459  0.858268  0.860140    0.859522
# 2          5  0.027397  0.052980  0.050633  0.028169  0.000000    0.031836
# 3          5  0.747826  0.761506  0.716667  0.766520  0.800000    0.758504
# 4          5       NaN       NaN       NaN       NaN       NaN         NaN

# %%
def load_csi_dataset(path="/data/csi_datasets/shs100k2_test.csv", yt_metadata_path="/data/yt_metadata.parquet"):
    df_test = pd.read_csv(path, sep=";")
    df_metadata = pd.read_parquet(yt_metadata_path).reset_index()
    return df_metadata.loc[df_metadata.yt_id.isin(df_test.yt_id), 
                           ["yt_id", "title", "channel_name", "description"]].rename(
        {"title": "video_title"}, axis=1)

load_csi_dataset()
# Out:
# Running cells with 'py_entitymatching' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n py_entitymatching ipykernel --update-deps --force-reinstall'

# %% [markdown]
# # Test on test datasets

# %%
# this runs forever! thanks a lot...
def init_dataset_from_data(metadata_parquet_file, dataset_file, split='TEST', shs_side=False):
    
    def clean_string(text):
        import re
        pattern = re.compile('[^a-zA-Z0-9\s]')
        cleaned_text = re.sub(pattern, '', text)
        return cleaned_text

    """
    A = pd.read_parquet(path + table_filename).rename({"title": "video_title"}, axis=1).drop_duplicates(
        subset=["yt_id"]
    ).fillna('')
    A.description = A.description.apply(clean_string)
    B = copy.copy(A)
    """
    def get_dataset_df(path):
        data = pd.read_csv(path, sep=";")[["yt_id", "set_id"]]
        data["join_key"] = 1
        data = data.merge(data, on="join_key").drop("join_key", axis=1).rename(
            {"yt_id_x": "ltable_id", "yt_id_y": "rtable_id", "set_id_x": "set_id_a", 
            "set_id_y": "set_id_b"}, axis=1
        )
        data["label"] = (data.set_id_a == data.set_id_b).astype(int)
        return data

    df_dataset = get_dataset_df(dataset_file)
    df_metadata = pd.read_parquet(metadata_parquet_file).query(f"split == '{split}'")
    
    if shs_side:
        A = df_metadata[["yt_id", "title", "performer"]].drop_duplicates(
            subset=["yt_id"]).dropna(subset=["yt_id"]).rename({"title": "video_title", 
                                                               "performer": "channel_name"}, axis=1)
        A["description"] = 'DESCRIPTION'
        A["keywords"] = 'KEYWORDS'
    else:
        A = df_metadata[["yt_id", "video_title", "channel_name", "description", "keywords"]].drop_duplicates(
            subset=["yt_id"]).dropna(subset=["yt_id"])
    
    B = df_metadata[["yt_id", "video_title", "channel_name", "description", "keywords"]].drop_duplicates(
        subset=["yt_id"]).dropna(subset=["yt_id"])
    B.description = B.description.apply(clean_string)

    def enrich(pairs):
        data = pd.merge(
            A.add_prefix("ltable_").rename({"ltable_yt_id": "ltable_id"}, axis=1),
            pd.merge(
                pairs[["ltable_id", "rtable_id", "label"]],
                B.add_prefix("rtable_").rename({"rtable_yt_id": "rtable_id"}, axis=1),
                on="rtable_id",
                how="left"
                ), 
            on="ltable_id",
            how="right"
        )
        # id formatting
        data["_id"] = range(0, len(data))
        
        # col reordering
        data = data[['_id', 'ltable_id', 'rtable_id', 'ltable_video_title', 
                        'ltable_channel_name', 'ltable_description', 'ltable_keywords', 
                        'rtable_video_title', 'rtable_channel_name', 'rtable_description', 
                        'rtable_keywords', 'label']]
        return data
        
    S = enrich(df_dataset)

    datasets_dir = em.get_install_path() + os.sep + 'datasets'

    path_A = datasets_dir + os.sep + 'shs100k2test_yt_A.csv'
    path_B = datasets_dir + os.sep + 'shs100k2test_yt_B.csv'
    path_labeled_data = datasets_dir + os.sep + 'shs100k2test_yt_labeled.csv'

    os.remove(path_A) if os.path.exists(path_A) else None
    os.remove(path_B) if os.path.exists(path_B) else None
    os.remove(path_labeled_data) if os.path.exists(path_labeled_data) else None

    em.to_csv_metadata(A, path_A)
    em.to_csv_metadata(B, path_B)
    em.to_csv_metadata(S, path_labeled_data)

    # reading in
    A = em.read_csv_metadata(path_A, key='yt_id')
    B = em.read_csv_metadata(path_B, key='yt_id')

    S = em.read_csv_metadata(path_labeled_data, key='_id',
                            ltable=A, rtable=B, 
                            fk_ltable='ltable_id', fk_rtable='rtable_id')

    # remove the files
    os.remove(path_A) if os.path.exists(path_A) else None
    os.remove(path_B) if os.path.exists(path_B) else None
    os.remove(path_labeled_data) if os.path.exists(path_labeled_data) else None
    
    return A, B, S


dataset_file = "/data/csi_datasets/shs100k2_test.csv"

#A, B, S = init_dataset_from_data(metadata_parquet_file, dataset_file)
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
datasets_dir = em.get_install_path() + os.sep + 'datasets'

path_A = datasets_dir + os.sep + 'shs100k2test_yt_A.csv'
path_B = datasets_dir + os.sep + 'shs100k2test_yt_B.csv'
path_labeled_data = datasets_dir + os.sep + 'shs100k2test_yt_labeled.csv'

em.to_csv_metadata(A, path_A)
em.to_csv_metadata(B, path_B)
em.to_csv_metadata(S, path_labeled_data)
# Out:
# True

# %%
# Generate a set of features
#S = S.loc[S.ltable_id.isin(A.yt_id) & S.rtable_id.isin(B.yt_id)]

datasets_dir = em.get_install_path() + os.sep + 'datasets'
path_labeled_data = datasets_dir + os.sep + 'shs100k2test_yt_labeled.csv'

S = em.read_csv_metadata(path_labeled_data, key='_id',
                        ltable=A, rtable=B, 
                        fk_ltable='ltable_id', fk_rtable='rtable_id')

F = em.get_features_for_matching(A, B, validate_inferred_attr_types=False)


#  Split S into I an J
IJ = em.split_train_test(S, train_proportion=0.1, random_state=0)
I = IJ['train']
J = IJ['test']
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
J
# Out:
#                 _id    ltable_id    rtable_id  \
# 39014864   55171054  danXQQ5mjzE  84K0Ka7HZ3k
# 2887458     4120796  lFP7kMmQ40k  LBELgZB1v4Q
# 73283476  104934899  zmNqtKK9sEE  F3qqXqyaFsQ
# 33793735   47718821  I1aLSJyWrno  fUsDm6r2bBE
# 16759956   23700819  y_e-xRPx9ZA  fY28O2teFJw
# ...             ...          ...          ...
# 8518908    12275092  fTomm9sHUPA  8zyMz8_At5E
# 25740929   36212574  rAEglE08Ojs  9gPRqNJo22w
# 57666637   82159482  ItkUN1FOERI  wInkebWsbW4
# 71973797  103240650  mzh8my_iILY  RR89JVJqBYg
# 48559364   69169517  YZL7It9wrEk  9fvNM0iMo-Y
#
#                                                            ltable_video_title  \
# 39014864             LOUIE AUSTEN feat. SENOR COCONUT - Dreams are my reality
# 2887458                                    Pat Boone  - The Girl From Ipanema
# 73283476  Kirk Whalum - All I Do, Jazz, Funk, Fusion, Saxophone,Funky,The Man
# 33793735                    The Kenny Wayne Shepherd Band -  Oh, Pretty Woman
# 16759956                         Comfortably Numb [Pink Floyd cover] - Staind
# ...                                                                       ...
# 8518908                                          Beatles/Sweet Little Sixteen
# 25740929                            Fabrizio De andrè - Don Raffaè. con testo
# 57666637                                      Ride a White Swan by Pulse Beat
# 71973797                                    The Beatles - Misery (Audio Only)
# 48559364                                       I'd Climb the Highest Mountain
#
#           ltable_channel_name  \
# 39014864  progressivepicturez
# 2887458            TOTY ITALY
# 73283476      SAMMERIC BAILEY
# 33793735                Kyoto
# 16759956         Kevin Lehman
# ...                       ...
# 8518908               mfumi11
# 25740929        Savino Larosa
# 57666637            Liam Wood
# 71973797       JohnLennon1984
# 48559364  Keely Smith - Topic
#
#                                                                                            ltable_description  \
# 39014864  The production for Louie Austen.\r\nthe brand new music video of the Senor Coconut\r\ncollaborat...
# 2887458                                                                                                   NaN
# 73283476                                                                                          Kirk Whalum
# 33793735  DISCLAIMER: All photos,music and stills are copyrighted to their respective owners. No infringem...
# 16759956             Staind covering Comfortably Numb by Pink Floyd... best cover of this song ive ever heard
# ...                                                                                                       ...
# 8518908   The performance that flows to backing is done ..Last night in Hamburg.. \r\nlive. It seems that ...
# 25740929  Io mi chiamo Pasquale Cafiero \ne son brigadiere del carcere oinè \nio mi chiamo Cafiero Pasqual...
# 57666637            Electronic cover of Marc Bolan's Ride a White Swan by Pulse Beat Graham Vee and Matt Wood
# 71973797                                                                        track 2 from Please Please Me
# 48559364  Provided to YouTube by The state51 Conspiracy\n\nI'd Climb the Highest Mountain · Keely Smith\n\...
#
#                                                                                               ltable_keywords  \
# 39014864       ['Louie' 'Austen' 'reality' 'progressive' 'pictures' 'klein' 'records'\n 'bohusch' 'bointner']
# 2887458                                                                 ['Pat Boone' 'The Girl From Ipanema']
# 73283476                             ['Kirk walum' 'jazz' 'saxophone' 'Funk' 'All I Do' 'Fusion' 'legendary']
# 33793735                                           ['Kenny Wayne' 'Pretty Woman' 'Kenny Wayne Shepherd Band']
# 16759956                                                   ['comfortably numb' 'pink floyd' 'cover' 'staind']
# ...                                                                                                       ...
# 8518908                                                               ['Beatles/Last' 'night' 'in' 'Hamburg']
# 25740929  ['Fabrizio De André (Musical Artist)' "Don Raffae' (Musical Recording)"\n 'Music (TV Genre)' 'Te...
# 57666637                                                                                       ['Electronic']
# 71973797  ['The Beatles' 'Misery' 'Please Please Me' 'john lennon' 'paul mccartney'\n 'ringo star' 'george...
# 48559364                                        ['Keely Smith' 'Be My Love' "I'd Climb the Highest Mountain"]
#
#                                                          rtable_video_title  \
# 39014864    1976 - Freddy Fender - You'll Lose A Good Thing (Album Version)
# 2887458                                   Little Milton  -  Have Mercy Baby
# 73283476            Imagine Dragons - "Radioactive" Cover by Our Last Night
# 33793735                                    Be My Wife by  Anthony Reynolds
# 16759956                                     Deborah Blando - somente o sol
# ...                                                                     ...
# 8518908                                   Leon Redbone- Who's Honey Are You
# 25740929  Spider and The fly - The Kenny Wayne Shepherd Band & James Cotton
# 57666637                                 John Hiatt - Take Time To Know Her
# 71973797                                             Paul Anka "Puppy Love"
# 48559364      Tina Root (Of Switchblade Symphony) - Never Let Me Down Again
#
#                    rtable_channel_name  \
# 39014864            MJ's Vinyl Channel
# 2887458                      pghpookie
# 73283476                Our Last Night
# 33793735              Anthony Reynolds
# 16759956                  Darci Severo
# ...                                ...
# 8518908   Leon Redbone Tribute Channel
# 25740929                  Brenda Zarza
# 57666637                           CLM
# 71973797                   NRRArchives
# 48559364                    Ülka Pänti
#
#                                                                                            rtable_description  \
# 39014864  1976  Freddy Fender  Rock N Country  Youll Lose A Good Thing\nABC Dot 27 127 XOT\nVinyl LP Album...
# 2887458   Little Miltons remake of the Dominoes classic of the 50s This is from the 1966 album Little Milt...
# 73283476  Purchase the entire Summer of Covers EP on iTunes \nhttpsitunesapplecomusalbumsum\nCheck out htt...
# 33793735                                                                                     Bowie cover 2004
# 16759956  Somente o sol voc e eu\r\nEu quero mergulhar num beijo seu eu vejo luzes quando te sonho misturo...
# ...                                                                                                       ...
# 8518908   Leon Redbone Performs Whos Honey Are You\n\nFrom The Album Red To Blue\n\nWritten By Fred S Coot...
# 25740929                                      Spider and The fly  The Kenny Wayne Shepherd Band  James Cotton
# 57666637                                                       b side Percy Sledge song covered by John Hiatt
# 71973797                        Saturday Night BeechNut Show February 13 1960 Reuploaded with corrected audio
# 48559364                                                                                                  NaN
#
#                                                                                               rtable_keywords  \
# 39014864                                          ['Freddy Fender' "You'll Lose A Good Thing" '1976' 'Vinyl']
# 2887458                                              ['Northern' 'Soul' 'Oldies' 'Chicago' 'Little' 'Milton']
# 73283476  ['Radioactive' 'Imagine Dragons' 'Our Last Night' 'Pop Goes Punk'\n 'Cover Song' 'Drums' 'SJC' '...
# 33793735                                                                                                  NaN
# 16759956                                                                  ['Debora' 'Blando' 'somente' 'sol']
# ...                                                                                                       ...
# 8518908   ['leon redbone' 'red to blue' "Who's Honey Are You" 'kentucky' 'new'\n 'orleans' 'jazz' 'blues' ...
# 25740929                                                                                     ['Rock' 'Blues']
# 57666637                                                                                       ['John Hiatt']
# 71973797                                                                                                  NaN
# 48559364                    ['Tina' 'Root' 'Of' 'Switchblade' 'Symphony' 'Never' 'Let' 'Me' 'Down'\n 'Again']
#
#           label
# 39014864      0
# 2887458       0
# 73283476      0
# 33793735      0
# 16759956      0
# ...         ...
# 8518908       0
# 25740929      0
# 57666637      0
# 71973797      0
# 48559364      0
#
# [69870349 rows x 12 columns]

# %%
# Out:
#                 _id    ltable_id    rtable_id  \
# 0          83750301  VjufWQQRPN4  I4Ep3q3Zrjo
# 1          66273662  JlPFexdtYP0  XagQ3owbBEM
# 2          72306030  5Ep_vLeXKKM  C_HLqljWjFY
# 3          68729384  syw75H4-5Qk  Aw38mHi4oVs
# 4          65469468  PNmFypZlIaM  vcZeNncytkM
# ...             ...          ...          ...
# 77633716   12275092  fTomm9sHUPA  8zyMz8_At5E
# 77633717   36212574  rAEglE08Ojs  9gPRqNJo22w
# 77633718   82159482  ItkUN1FOERI  wInkebWsbW4
# 77633719  103240650  mzh8my_iILY  RR89JVJqBYg
# 77633720   69169517  YZL7It9wrEk  9fvNM0iMo-Y
#
#                                                                           ltable_video_title  \
# 0                        Teenage Dirtbag - Andrew Dentons Musical Challenge - Adam Brand.wmv
# 1         Animals / Maps - Maroon 5 Mashup Cover (A Cappella) -- Backtrack feat. Dara Orland
# 2                                      Land of Confusion - SACRA/PROFANA & 2014 SCI Students
# 3                                                                            Sepultura - War
# 4                                                  Cass Daley - Put the Blame on Mame (1946)
# ...                                                                                      ...
# 77633716                                                        Beatles/Sweet Little Sixteen
# 77633717                                           Fabrizio De andrè - Don Raffaè. con testo
# 77633718                                                     Ride a White Swan by Pulse Beat
# 77633719                                                   The Beatles - Misery (Audio Only)
# 77633720                                                      I'd Climb the Highest Mountain
#
#            ltable_channel_name  \
# 0         speedboatsforbrkfast
# 1             Backtrack Vocals
# 2                SACRA/PROFANA
# 3                 killinemfast
# 4                   Cass Daley
# ...                        ...
# 77633716               mfumi11
# 77633717         Savino Larosa
# 77633718             Liam Wood
# 77633719        JohnLennon1984
# 77633720   Keely Smith - Topic
#
#                                                                                            ltable_description  \
# 0                                                                         I dont own the rights to this music
# 1         Check out our Patreon page to become a Backtrack Patron: http://www.patreon.com/backtrackvocals\...
# 2         SACRA/PROFANA & students from our 2014 Summer Choral Intensive in this cover of "Land of Confusi...
# 3         Artist: Sepultura\nTrack: War\nAlbum: Blood-Rooted\nCopyright © Roadrunner Records 1997\n\nLyric...
# 4         Release on Decca -- 18879. \n\nCass Daley recorded her version for Decca in 1946, and it sold 13...
# ...                                                                                                       ...
# 77633716  The performance that flows to backing is done ..Last night in Hamburg.. \r\nlive. It seems that ...
# 77633717  Io mi chiamo Pasquale Cafiero \ne son brigadiere del carcere oinè \nio mi chiamo Cafiero Pasqual...
# 77633718            Electronic cover of Marc Bolan's Ride a White Swan by Pulse Beat Graham Vee and Matt Wood
# 77633719                                                                        track 2 from Please Please Me
# 77633720  Provided to YouTube by The state51 Conspiracy\n\nI'd Climb the Highest Mountain · Keely Smith\n\...
#
#                                                                                               ltable_keywords  \
# 0                             ['Teenage' 'Dirtbag' 'Andrew' 'Dentons' 'Musical' 'Challenge' 'Adam'\n 'Brand']
# 1         ['Animals' 'Maroon 5' 'Maps' 'Adam Levine (Celebrity)'\n 'Pentatonix (Musical Group)' 'A Cappell...
# 2         ['phil collins' 'sacra profana' 'genesis' 'disturbed' 'land of confusion'\n 'a cappella' 'choir'...
# 3         ['Sepultura War' 'Sepultura' 'War' 'Blood-Rooted' 'Sepultura Blood-Rooted'\n '1997' 'Ratamahatta...
# 4                                                                                                         NaN
# ...                                                                                                       ...
# 77633716                                                              ['Beatles/Last' 'night' 'in' 'Hamburg']
# 77633717  ['Fabrizio De André (Musical Artist)' "Don Raffae' (Musical Recording)"\n 'Music (TV Genre)' 'Te...
# 77633718                                                                                       ['Electronic']
# 77633719  ['The Beatles' 'Misery' 'Please Please Me' 'john lennon' 'paul mccartney'\n 'ringo star' 'george...
# 77633720                                        ['Keely Smith' 'Be My Love' "I'd Climb the Highest Mountain"]
#
#                                                          rtable_video_title  \
# 0                                             the vandals hocus pocus N.W.O
# 1                           Little Walter /  Boom, Boom Out Goes the Lights
# 2                                   Nick Jonas - Jealous [Andie Case Cover]
# 3                                 Precious Wilson - Only The Strong Survive
# 4                  Webb Wilder - The Devil's Right Hand (Steve Earle cover)
# ...                                                                     ...
# 77633716                                  Leon Redbone- Who's Honey Are You
# 77633717  Spider and The fly - The Kenny Wayne Shepherd Band & James Cotton
# 77633718                                 John Hiatt - Take Time To Know Her
# 77633719                                             Paul Anka "Puppy Love"
# 77633720      Tina Root (Of Switchblade Symphony) - Never Let Me Down Again
#
#                    rtable_channel_name  \
# 0                           DECIDER911
# 1                           1Bluesboy1
# 2                   SIZO ENTERTAINMENT
# 3            Alieno🎵 12’’ & 7’’ Single
# 4                             denmarst
# ...                                ...
# 77633716  Leon Redbone Tribute Channel
# 77633717                  Brenda Zarza
# 77633718                           CLM
# 77633719                   NRRArchives
# 77633720                    Ülka Pänti
#
#                                                                                            rtable_description  \
# 0                                                          BILDERBERG SKULL  BONES bohiemian grove freemasons
# 1                                                                                                 1950s sides
# 2         BRAND NEW cover track is up by Andie Case \n\nPlease remember to subsribe this channel to stay u...
# 3                                                                                       1987 Extended Version
# 4         Upload mp3s  httpwwwmp32tubecom Webb Wilder and the Beatnecks cover Steve Earles song on their 1...
# ...                                                                                                       ...
# 77633716  Leon Redbone Performs Whos Honey Are You\n\nFrom The Album Red To Blue\n\nWritten By Fred S Coot...
# 77633717                                      Spider and The fly  The Kenny Wayne Shepherd Band  James Cotton
# 77633718                                                       b side Percy Sledge song covered by John Hiatt
# 77633719                        Saturday Night BeechNut Show February 13 1960 Reuploaded with corrected audio
# 77633720                                                                                                  NaN
#
#                                                                                               rtable_keywords  \
# 0                                                                           ['vandals' '9/11' 'inside' 'job']
# 1                                                                                       ['blues' 'harmonica']
# 2         ['Andie Case' 'SIZO' 'SIZO ENTERTAINMENT' 'Andie' 'Case'\n 'Girl singing in car' 'Patrick Zola' ...
# 3         ['funk' 'boogie' 'soul' 'disco' 'electro' 'groove' '12' 'inch' 'hd' 'hq'\n 'alieno' 'maxi' 'Prec...
# 4                                        ['music' 'rock' 'alturnativecountry' 'cowpunk' 'SteveEarle' 'cover']
# ...                                                                                                       ...
# 77633716  ['leon redbone' 'red to blue' "Who's Honey Are You" 'kentucky' 'new'\n 'orleans' 'jazz' 'blues' ...
# 77633717                                                                                     ['Rock' 'Blues']
# 77633718                                                                                       ['John Hiatt']
# 77633719                                                                                                  NaN
# 77633720                    ['Tina' 'Root' 'Of' 'Switchblade' 'Symphony' 'Never' 'Let' 'Me' 'Down'\n 'Again']
#
#           label
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 77633716      0
# 77633717      0
# 77633718      0
# 77633719      0
# 77633720      0
#
# [77633721 rows x 12 columns]

# %%
I
# Out:
#                 _id    ltable_id    rtable_id  \
# 58810578   83750301  VjufWQQRPN4  I4Ep3q3Zrjo
# 46589507   66273662  JlPFexdtYP0  XagQ3owbBEM
# 50615724   72306030  5Ep_vLeXKKM  C_HLqljWjFY
# 48297439   68729384  syw75H4-5Qk  Aw38mHi4oVs
# 46120367   65469468  PNmFypZlIaM  vcZeNncytkM
# ...             ...          ...          ...
# 58554051   83411539  yA-G81xJT3U  emZ4qo73fUk
# 60969723   86883281  Q397urTG4Ls  MOtFA4FEXvY
# 38712131   54755907  N-Q7TrGqN1k  olzGO7gvU7w
# 2215104     3189379  H0_rHGGltG0  FCh6zr7eyYQ
# 75434668  107974000  ENQ0hXmkx1Q  kuXh5z9KVH8
#
#                                                                           ltable_video_title  \
# 58810578                 Teenage Dirtbag - Andrew Dentons Musical Challenge - Adam Brand.wmv
# 46589507  Animals / Maps - Maroon 5 Mashup Cover (A Cappella) -- Backtrack feat. Dara Orland
# 50615724                               Land of Confusion - SACRA/PROFANA & 2014 SCI Students
# 48297439                                                                     Sepultura - War
# 46120367                                           Cass Daley - Put the Blame on Mame (1946)
# ...                                                                                      ...
# 58554051                                                      Everything I Do Gonna Be Funky
# 60969723                                                          The Blasters - I'm Shakin'
# 38712131                                              "I Can't Keep From Crying"   Al Kooper
# 2215104                                                             Chet Atkins "Yesterdays"
# 75434668                                                             A Man Needs A Maid-Dala
#
#            ltable_channel_name  \
# 58810578  speedboatsforbrkfast
# 46589507      Backtrack Vocals
# 50615724         SACRA/PROFANA
# 48297439          killinemfast
# 46120367            Cass Daley
# ...                        ...
# 58554051           Man Moncabo
# 60969723                holsty
# 38712131   Cuthbert J. Twillie
# 2215104              daffydoug
# 75434668        Bluematter1969
#
#                                                                                            ltable_description  \
# 58810578                                                                  I dont own the rights to this music
# 46589507  Check out our Patreon page to become a Backtrack Patron: http://www.patreon.com/backtrackvocals\...
# 50615724  SACRA/PROFANA & students from our 2014 Summer Choral Intensive in this cover of "Land of Confusi...
# 48297439  Artist: Sepultura\nTrack: War\nAlbum: Blood-Rooted\nCopyright © Roadrunner Records 1997\n\nLyric...
# 46120367  Release on Decca -- 18879. \n\nCass Daley recorded her version for Decca in 1946, and it sold 13...
# ...                                                                                                       ...
# 58554051  Allen Toussaint – Toussaint - Scepter Records – SPS 24003\nFormat: Vinyl, LP, Album - Date: 1970...
# 60969723  Artist: The Blasters\nAlbum: The Blasters (1981)\nTrack:  I'm Shakin'\n\nI do not claim to own t...
# 38712131                                    With The Blues Project. Danny Kalb on Guitar. "Chip on it, baby!"
# 2215104       From country to the most sophisticated guitar playing ever..Chet could do it all. Here's proof.
# 75434668  Cover of Neil Young's Harvest number by Dala. Dala is a Canadian acoustic-folk two-piece musical...
#
#                                                                                               ltable_keywords  \
# 58810578                      ['Teenage' 'Dirtbag' 'Andrew' 'Dentons' 'Musical' 'Challenge' 'Adam'\n 'Brand']
# 46589507  ['Animals' 'Maroon 5' 'Maps' 'Adam Levine (Celebrity)'\n 'Pentatonix (Musical Group)' 'A Cappell...
# 50615724  ['phil collins' 'sacra profana' 'genesis' 'disturbed' 'land of confusion'\n 'a cappella' 'choir'...
# 48297439  ['Sepultura War' 'Sepultura' 'War' 'Blood-Rooted' 'Sepultura Blood-Rooted'\n '1997' 'Ratamahatta...
# 46120367                                                                                                  NaN
# ...                                                                                                       ...
# 58554051    ['Allen Toussain' 'Funk / Soul' 'Rhythm & Blues' 'Bayou Funk'\n 'Everything I Do Gonna Be Funky']
# 60969723                                                                            ['Blasters' 'Rockabilly']
# 38712131  ['Bob' 'Dylan' 'Mike' 'Bloomfield' 'danny' 'kalb' 'blood' 'sweat' 'and'\n 'tears' 'lynyrd' 'skyn...
# 2215104                            ['chet atkins' 'mr guitar' 'yerterdays' 'finger pickin' 'guitar virtuoso']
# 75434668                                                                                                  NaN
#
#                                                       rtable_video_title  \
# 58810578                                   the vandals hocus pocus N.W.O
# 46589507                 Little Walter /  Boom, Boom Out Goes the Lights
# 50615724                         Nick Jonas - Jealous [Andie Case Cover]
# 48297439                       Precious Wilson - Only The Strong Survive
# 46120367        Webb Wilder - The Devil's Right Hand (Steve Earle cover)
# ...                                                                  ...
# 58554051  BARRY MANILOW TRYING TO GET THE FEELING AGAIN Lyrics on screen
# 60969723                                                 Flunk - See You
# 38712131              TIM GOODMAN - GROWIN' UP (Similar to TOM JOHNSTON)
# 2215104                       London Starlight Orchestra - All Time High
# 75434668                     loggins & messina - A Love Song - Full Sail
#
#                 rtable_channel_name  \
# 58810578                 DECIDER911
# 46589507                 1Bluesboy1
# 50615724         SIZO ENTERTAINMENT
# 48297439  Alieno🎵 12’’ & 7’’ Single
# 46120367                   denmarst
# ...                             ...
# 58554051                   JM TAPPF
# 60969723                    TotesMe
# 38712131               cruisinmusic
# 2215104             Jasper & Harley
# 75434668                   ByranBig
#
#                                                                                            rtable_description  \
# 58810578                                                   BILDERBERG SKULL  BONES bohiemian grove freemasons
# 46589507                                                                                          1950s sides
# 50615724  BRAND NEW cover track is up by Andie Case \n\nPlease remember to subsribe this channel to stay u...
# 48297439                                                                                1987 Extended Version
# 46120367  Upload mp3s  httpwwwmp32tubecom Webb Wilder and the Beatnecks cover Steve Earles song on their 1...
# ...                                                                                                       ...
# 58554051  This video have the purpose of to help learning of the easy way  the pronunciation of the words ...
# 60969723
# 38712131                                                                            from album FOOTSTEPS 1981
# 2215104             London Starlight Orchestra performs All Time High from the James Bond film Octopussy 1983
# 75434668                                           LogginsandMessina loggins  messina  A Love Song  Full Sail
#
#                                                                                               rtable_keywords  \
# 58810578                                                                    ['vandals' '9/11' 'inside' 'job']
# 46589507                                                                                ['blues' 'harmonica']
# 50615724  ['Andie Case' 'SIZO' 'SIZO ENTERTAINMENT' 'Andie' 'Case'\n 'Girl singing in car' 'Patrick Zola' ...
# 48297439  ['funk' 'boogie' 'soul' 'disco' 'electro' 'groove' '12' 'inch' 'hd' 'hq'\n 'alieno' 'maxi' 'Prec...
# 46120367                                 ['music' 'rock' 'alturnativecountry' 'cowpunk' 'SteveEarle' 'cover']
# ...                                                                                                       ...
# 58554051  ["Tryin' To Get The Feeling Again" 'Lyrics' 'Full' 'Song'\n 'Barry Manilow (Musical Artist)' 'Al...
# 60969723                                                                                ['Flunk' 'See' 'You']
# 38712131                                                                               ['cruisinmusic' 'AOR']
# 2215104   ['London' 'Starlight' 'Orchestra' 'all' 'time' 'high' 'james' 'bond' '007'\n 'music' 'octopussy'...
# 75434668                                                  ['loggins' '&messina' 'ALove' 'Song' 'Full' 'Sail']
#
#           label
# 58810578      0
# 46589507      0
# 50615724      0
# 48297439      0
# 46120367      0
# ...         ...
# 58554051      0
# 60969723      0
# 38712131      0
# 2215104       0
# 75434668      0
#
# [7763372 rows x 12 columns]

# %%
# Convert the I into a set of feature vectors using F
H = em.extract_feature_vecs(I, ignore_index=True, 
                            feature_table=F, 
                            attrs_after='label',
                            show_progress=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-01f8cd7ad3c0> in <module>
#       3                             feature_table=F,
#       4                             attrs_after='label',
# ----> 5                             show_progress=False)
#
# TypeError: extract_feature_vecs() got an unexpected keyword argument 'ignore_index'

# %%
rf.predict(table=H, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'], 
              append=True, target_attr='predicted', inplace=False, return_probs=True,
                        probs_attr='proba')
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-85-fb5f9f978c03> in <module>
#       1 rf.predict(table=H, exclude_attrs=['_id', 'ltable_id', 'rtable_id', 'label'],
#       2               append=True, target_attr='predicted', inplace=False, return_probs=True,
# ----> 3                         probs_attr='proba')
#       4
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/matcher/mlmatcher.py in predict(self, x, table, exclude_attrs, target_attr, append, return_probs, probs_attr, inplace)
#     237         # then call the appropriate predict method.
#     238         elif table is not None and exclude_attrs is not None:
# --> 239             y = self._predict_ex_attrs(table, exclude_attrs, return_prob=return_probs)
#     240             # If the append is True, update the table
#     241             if target_attr is not None and append is True:
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/matcher/mlmatcher.py in _predict_ex_attrs(self, table, exclude_attrs, return_prob)
#     177
#     178         # Do the predictions and return the probabilities (if required)
# --> 179         res = self._predict_sklearn(x, check_rem=False, return_prob=return_prob)
#     180         return res
#     181
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/py_entitymatching/matcher/mlmatcher.py in _predict_sklearn(self, x, check_rem, return_prob)
#     135         x = self._get_data_for_sklearn(x, check_rem=check_rem)
#     136         # Call the underlying predict function.
# --> 137         y = self.clf.predict(x)
#     138         if not return_prob:
#     139             # Return the predictions
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     669             classes corresponds to that in the attribute :term:`classes_`.
#     670         """
# --> 671         check_is_fitted(self)
#     672         # Check data
#     673         X = self._validate_X_predict(X)
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /data/miniconda3/envs/magellan/lib/python3.7/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1017
#    1018     if not attrs:
# -> 1019         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1020
#    1021
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
rf
